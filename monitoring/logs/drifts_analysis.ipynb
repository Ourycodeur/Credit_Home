# %%
import pandas as pd

# %%
reference = pd.read_csv("C:\\Users\\El. OURY BALDE\\Documents\\P8\\dataset\\credit_accord.csv")

# %%
production = pd.read_json(
    "../logs/prediction_logs.jsonl",
    lines = True
)

# %%
production_features = pd.json_normalize(
    production["input_data"]
)
